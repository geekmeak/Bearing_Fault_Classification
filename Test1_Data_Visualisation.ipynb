# %%
import numpy as np
import pandas as pd

# %%
test1 = "C:/Users/ashees/Desktop/IMS/1st_test"

# %%
import os
import glob
import itertools

# %%
test1_file = glob.glob(test1 + "/*")
print("Total number of files inn test1: ", len(test1_file))
# Out:
# Total number of files inn test1:  2156

# %%
T1= []

for i in range(len(test1_file)):
    
    temp = pd.read_csv(test1_file[i], sep='\s+', header=None)
    T1.append(temp)

# %%
Test1 = pd.concat(T1)

# %%
Test1.shape
# Out:
# (44154880, 8)

# %%
test1_ch1 = Test1[[0]]
test1_ch2 = Test1[[1]]
test1_ch3 = Test1[[2]]
test1_ch4 = Test1[[3]]
test1_ch5 = Test1[[4]]
test1_ch6 = Test1[[5]]
test1_ch7 = Test1[[6]]
test1_ch8 = Test1[[7]]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
time_steps = np.arange(len(Test1))

# %%
plt.figure(figsize=(30,20))


plt.subplot(421)
plt.plot(time_steps,test1_ch1,'g')
plt.title('Bearing_1 ch1')

plt.subplot(422)
plt.plot(time_steps,test1_ch2,'g')
plt.title('Bearing_1 ch2')

plt.subplot(423)
plt.plot(time_steps,test1_ch3)
plt.title('Bearing_2 ch1')

plt.subplot(424)
plt.plot(time_steps,test1_ch4)
plt.title('Bearing_2 ch2')

plt.subplot(425)
plt.plot(time_steps,test1_ch5,'m')
plt.title('Bearing_3 ch1')

plt.subplot(426)
plt.plot(time_steps,test1_ch6,'m')
plt.title('Bearing_3 ch2')

plt.subplot(427)
plt.plot(time_steps,test1_ch7,'r')
plt.title('Bearing_4 ch1')

plt.subplot(428)
plt.plot(time_steps,test1_ch8,'r')
plt.title('Bearing_4 ch2')

plt.show()
